# %% [markdown]
# # Systems Check
# ## Kendall Williams
# ### 8/20/2025
# In this class I want to learn what Python is.
# 1. I also want to learn how to use python and what I can use it for.
# - this is a list
# __this is bold__
# *this is italic*
#
# ![image.png](attachment:1973330d-37f2-4499-88bd-b769b0840b01.png)
